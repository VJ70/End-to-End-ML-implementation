# %%
import yaml
yaml_file_path= "test.yaml"
with open(yaml_file_path, 'r') as f:
    data = yaml.safe_load(f)
print(data)
print(type(data))
# Out:
# {'name': 'Vaish', 'email': 'vaishnavi7a7@gmail.com'}
# <class 'dict'>

# %%
import os

# %%
from box import ConfigBox
d= ConfigBox(data)
d
# Out:
# ConfigBox({'name': 'Vaish', 'email': 'vaishnavi7a7@gmail.com'})

# %%
type(d)
# Out:
# box.config_box.ConfigBox

# %%
d.name
# Out:
# 'Vaish'

# %%
d.email
# Out:
# 'vaishnavi7a7@gmail.com'
